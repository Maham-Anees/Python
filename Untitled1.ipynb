# %% [markdown]
# My code

# %%
"""
Maham Anees
I live with my parents
"""






print("M           M")
print("M   M    M   M")
print("M     M      M")
print("M            M")
print("M            M")
print("M            M")
print("M            M")


print("      A      ")
print("   A     A   ")
print("A           A")
print("A  A  A  A  A")
print("A           A")
print("A           A")
print("A           A")
